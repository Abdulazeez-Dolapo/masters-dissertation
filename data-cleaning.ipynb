# %%
# Libraries imports
import pandas as pd

# %%
# Load data
data = pd.read_csv('./data/players_22.csv')
# Out:
# /var/folders/rr/1c7n7djx6pb5nxys6_7my93m0000gn/T/ipykernel_10520/66362795.py:2: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('./data/players_22.csv')

# %%
# Remove unused columns from the data
columns_to_remove = [
   'sofifa_id',
   'player_url',
   'short_name',
   'long_name',
   'club_position',
   'dob',
   'club_team_id',
   'league_level',
   'club_jersey_number',
   'club_loaned_from',
   'club_joined',
   'nationality_id',
   'nation_team_id',
   'nation_position',
   'nation_jersey_number',
   'body_type',
   'real_face',
   'release_clause_eur',
   'player_tags',
   'player_traits',
   'goalkeeping_diving',
   'goalkeeping_handling',
   'goalkeeping_kicking',
   'goalkeeping_positioning',
   'goalkeeping_reflexes',
   'goalkeeping_speed',
   'ls',
   'st',
   'rs',
   'lw',
   'lf',
   'cf',
   'rf',
   'rw',
   'lam',
   'cam',
   'ram',
   'lm',
   'lcm',
   'cm',
   'rcm',
   'rm',
   'lwb',
   'ldm',
   'cdm',
   'rdm',
   'rwb',
   'lb',
   'lcb',
   'cb',
   'rcb',
   'rb',
   'gk',
   'player_face_url',
   'club_logo_url',
   'club_flag_url',
   'nation_logo_url',
   'nation_flag_url'
]
data = data.drop(columns=columns_to_remove)

data
# Out:
#       player_positions  overall  potential    value_eur  wage_eur  age  \
# 0           RW, ST, CF       93         93   78000000.0  320000.0   34
# 1                   ST       92         92  119500000.0  270000.0   32
# 2               ST, LW       91         91   45000000.0  270000.0   36
# 3              LW, CAM       91         91  129000000.0  270000.0   29
# 4              CM, CAM       91         91  125500000.0  350000.0   30
# ...                ...      ...        ...          ...       ...  ...
# 19234              CDM       47         52      70000.0    1000.0   22
# 19235               CM       47         59     110000.0     500.0   19
# 19236               CM       47         55     100000.0     500.0   21
# 19237               ST       47         60     110000.0     500.0   19
# 19238              CAM       47         60     110000.0     500.0   19
#
#        height_cm  weight_kg            club_name  \
# 0            170         72  Paris Saint-Germain
# ...

# %%
# Rename 'player_positions' column to 'position'
data.rename(columns={ 'player_positions': 'position' }, inplace=True)

# Update position based on the first item in the comma-separated values.
# For example, a player can have his positions as "LCB, RCB, CB". In this case,
# We select LCB as the player's primary position and update the column's value based on that.
data['position'] = data['position'].str.split(',').str[0]

# Map values to corresponding positions
position_mapping = {
   'GK': 'Goalkeeper',
   'RCB': 'Defender',
   'LCB': 'Defender',
   'RWB': 'Defender',
   'LWB': 'Defender',
   'RB': 'Defender',
   'LB': 'Defender',
   'CB': 'Defender',
   'RCM': 'Midfielder',
   'LCM': 'Midfielder',
   'RDM': 'Midfielder',
   'LDM': 'Midfielder',
   'CDM': 'Midfielder',
   'RAM': 'Midfielder',
   'LAM': 'Midfielder',
   'CAM': 'Midfielder',
   'RM': 'Midfielder',
   'LM': 'Midfielder',
   'CM': 'Midfielder',
   'RW': 'Forward',
   'LW': 'Forward',
   'RF': 'Forward',
   'LF': 'Forward',
   'RS': 'Forward',
   'LS': 'Forward',
   'ST': 'Forward',
   'CF': 'Forward',
}
data['position'] = data['position'].map(position_mapping)

data
# Out:
#          position  overall  potential    value_eur  wage_eur  age  height_cm  \
# 0         Forward       93         93   78000000.0  320000.0   34        170
# 1         Forward       92         92  119500000.0  270000.0   32        185
# 2         Forward       91         91   45000000.0  270000.0   36        187
# 3         Forward       91         91  129000000.0  270000.0   29        175
# 4      Midfielder       91         91  125500000.0  350000.0   30        181
# ...           ...      ...        ...          ...       ...  ...        ...
# 19234  Midfielder       47         52      70000.0    1000.0   22        180
# 19235  Midfielder       47         59     110000.0     500.0   19        175
# 19236  Midfielder       47         55     100000.0     500.0   21        178
# 19237     Forward       47         60     110000.0     500.0   19        173
# 19238  Midfielder       47         60     110000.0     500.0   19        167
#
# ...

# %%
# Remove rows with missing values
data.dropna(inplace=True)

data
# Out:
#          position  overall  potential    value_eur  wage_eur  age  height_cm  \
# 0         Forward       93         93   78000000.0  320000.0   34        170
# 1         Forward       92         92  119500000.0  270000.0   32        185
# 2         Forward       91         91   45000000.0  270000.0   36        187
# 3         Forward       91         91  129000000.0  270000.0   29        175
# 4      Midfielder       91         91  125500000.0  350000.0   30        181
# ...           ...      ...        ...          ...       ...  ...        ...
# 19234  Midfielder       47         52      70000.0    1000.0   22        180
# 19235  Midfielder       47         59     110000.0     500.0   19        175
# 19236  Midfielder       47         55     100000.0     500.0   21        178
# 19237     Forward       47         60     110000.0     500.0   19        173
# 19238  Midfielder       47         60     110000.0     500.0   19        167
#
# ...

# %%
# Reset index and create a new cleaned file
data = data.reset_index(drop=True)
data.to_csv('./data/cleaned-players22.csv')
